# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Memuat dataset dengan menggunakan library pandas menjadi dataframe. (2
# point)

# %%
import pandas as pd

# Data dari 10 jurnal tambahan sebagai contoh
data = [
    {
        "No": 1,
        "JUDUL": "A hybrid deep learning-based fruit classification using attention model and convolution autoencoder",
        "LINK": "https://link.springer.com/article/10.1007/s40747-020-00192-x",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "Springer",
        "Research Objective": "Mengembangkan sistem klasifikasi buah berbasis autoencoder dan attention mechanism",
        "Dataset": "Dua dataset buah (tidak disebutkan detail)",
        "Techniques": "Convolutional Autoencoder (CAE), Attention DenseNet",
        "Strengh and weakhnes": "Kelebihan: akurasi tinggi, efisien. Kekurangan: model kompleks",
        "Summarize manual": "CAE digunakan untuk ekstraksi fitur awal, lalu Attention DenseNet untuk klasifikasi"
    },
    {
        "No": 2,
        "JUDUL": "A multi-fused convolutional neural network model for fruit image classification",
        "LINK": "https://www.sciencedirect.com/science/article/pii/S2666307424000354",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "Elsevier",
        "Research Objective": "Meningkatkan akurasi klasifikasi buah dengan gabungan CNN",
        "Dataset": "Fruit-360",
        "Techniques": "EfficientNet-B0, MobileNetV2, ResNet50V2 (ensemble)",
        "Strengh and weakhnes": "Kelebihan: akurasi 99.32%. Kekurangan: potensi overfitting",
        "Summarize manual": "Tiga model CNN digabungkan untuk klasifikasi buah yang lebih akurat"
    },
    {
        "No": 3,
        "JUDUL": "Fruit Image Classification Model Based on MobileNetV2 with Deep Transfer Learning Technique",
        "LINK": "https://www.mdpi.com/2071-1050/15/3/1906",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "MDPI",
        "Research Objective": "Menggunakan MobileNetV2 dengan transfer learning untuk klasifikasi buah",
        "Dataset": "Dataset 40 jenis buah",
        "Techniques": "MobileNetV2, Transfer Learning",
        "Strengh and weakhnes": "Kelebihan: ringan dan cepat. Kekurangan: terbatas pada klasifikasi",
        "Summarize manual": "Transfer learning mempercepat dan meningkatkan akurasi klasifikasi buah"
    },
    {
        "No": 4,
        "JUDUL": "Classifying Healthy and Defective Fruits with a Multi-Input Architecture and CNN Models",
        "LINK": "https://arxiv.org/abs/2410.11108",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "arXiv",
        "Research Objective": "Mengklasifikasi buah sehat dan rusak menggunakan arsitektur multi-input",
        "Dataset": "RGB dan siluet apel dan mangga",
        "Techniques": "MobileNetV2, VGG16",
        "Strengh and weakhnes": "Kelebihan: akurasi tinggi. Kekurangan: hanya dua jenis buah",
        "Summarize manual": "Menggunakan dua input citra untuk klasifikasi kesehatan buah"
    },
    {
        "No": 5,
        "JUDUL": "Automatic Fruits Freshness Classification Using CNN and Transfer Learning",
        "LINK": "https://www.mdpi.com/2076-3417/13/14/8087",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "MDPI",
        "Research Objective": "Klasifikasi kesegaran buah secara otomatis",
        "Dataset": "3 dataset buah segar dan busuk",
        "Techniques": "ResNet50, VGG16, InceptionV3 + Transfer Learning",
        "Strengh and weakhnes": "Kelebihan: akurasi tinggi (99.8%). Kekurangan: komputasi tinggi",
        "Summarize manual": "Berbagai CNN digunakan untuk menilai kesegaran buah dari gambar"
    },
    {
        "No": 6,
        "JUDUL": "Attention-Aware CNN for Fruit Image Classification",
        "LINK": "https://drpress.org/ojs/index.php/HSET/article/view/5806",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "HSET",
        "Research Objective": "Meningkatkan akurasi CNN dengan modul perhatian",
        "Dataset": "Fruit360 dan dataset dunia nyata",
        "Techniques": "CNN + CBAM (Attention Module)",
        "Strengh and weakhnes": "Kelebihan: akurasi meningkat. Kekurangan: tidak terlalu efektif di data dunia nyata",
        "Summarize manual": "CBAM ditambahkan ke CNN untuk membantu CNN fokus pada bagian penting citra"
    },
    {
        "No": 7,
        "JUDUL": "Fruit Quality Assessment with Densely Connected Convolutional Neural Network",
        "LINK": "https://arxiv.org/abs/2212.04255",
        "TAHUN TERBIT": 2022,
        "PUBLISHER": "arXiv",
        "Research Objective": "Menilai kualitas buah menggunakan DenseNet",
        "Dataset": "19.526 gambar 6 jenis buah",
        "Techniques": "DenseNet",
        "Strengh and weakhnes": "Kelebihan: akurasi 99.67%. Kekurangan: hanya 6 jenis buah",
        "Summarize manual": "DenseNet digunakan untuk klasifikasi tingkat kualitas buah berdasarkan gambar"
    },
    {
        "No": 8,
        "JUDUL": "Fruit Quality and Defect Image Classification with Conditional GAN Data Augmentation",
        "LINK": "https://arxiv.org/abs/2104.05647",
        "TAHUN TERBIT": 2021,
        "PUBLISHER": "arXiv",
        "Research Objective": "Augmentasi data kualitas buah dengan Conditional GAN",
        "Dataset": "2690 gambar lemon",
        "Techniques": "VGG16, Conditional GAN",
        "Strengh and weakhnes": "Kelebihan: akurasi meningkat. Kekurangan: dataset kecil",
        "Summarize manual": "Conditional GAN digunakan untuk menambah data klasifikasi kualitas buah"
    },
    {
        "No": 9,
        "JUDUL": "A Vision-Based Method Utilizing Deep CNNs for Fruit Variety Classification in Uncertainty Conditions of Retail Sales",
        "LINK": "https://www.mdpi.com/2076-3417/9/19/3971",
        "TAHUN TERBIT": 2019,
        "PUBLISHER": "MDPI",
        "Research Objective": "Klasifikasi varietas buah di lingkungan retail yang bervariasi",
        "Dataset": "Gambar buah dari toko retail",
        "Techniques": "Deep CNN",
        "Strengh and weakhnes": "Kelebihan: akurat untuk retail. Kekurangan: dataset tidak terbuka",
        "Summarize manual": "CNN digunakan untuk klasifikasi buah dalam kondisi nyata di pasar/toko"
    },
    {
        "No": 10,
        "JUDUL": "Improving Classification Accuracy of Local Coconut Fruits with Image Augmentation and CNN",
        "LINK": "https://www.bright-journal.org/Journal/index.php/JADS/article/view/389",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "Journal of Applied Data Sciences",
        "Research Objective": "Meningkatkan klasifikasi kelapa lokal dengan augmentasi dan CNN",
        "Dataset": "Gambar kelapa lokal Indonesia",
        "Techniques": "VGG16 + Data Augmentation",
        "Strengh and weakhnes": "Kelebihan: akurasi meningkat. Kekurangan: dataset sangat spesifik",
        "Summarize manual": "Augmentasi gambar memperbaiki performa CNN dalam klasifikasi kelapa lokal"
    },
    {
        "No": 11,
        "JUDUL": "Efficient citrus fruit image classification via a hybrid hierarchical CNN",
        "LINK": "https://link.springer.com/article/10.1007/s11694-024-02973-1",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "Springer",
        "Research Objective": "Mengembangkan model klasifikasi buah jeruk menggunakan CNN hierarkis dan transfer learning",
        "Dataset": "280 gambar X-ray CT buah jeruk (mandarin)",
        "Techniques": "Custom CNN, Transfer Learning (VGG16, ResNet50, EfficientNetB0, dll)",
        "Strengh and weakhnes": "Kelebihan: Akurasi tinggi (98%). Kekurangan: Dataset spesifik (X-ray)",
        "Summarize manual": "Menggunakan CNN hierarkis dengan transfer learning untuk klasifikasi buah jeruk berdasarkan citra X-ray"
    },
    {
        "No": 12,
        "JUDUL": "Fruit Image Classification Using Deep Learning",
        "LINK": "https://www.sciencedirect.com/science/article/pii/S1546221822007135",
        "TAHUN TERBIT": 2022,
        "PUBLISHER": "ScienceDirect",
        "Research Objective": "Mengklasifikasikan gambar buah menggunakan kombinasi CNN, RNN, dan LSTM",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "CNN, RNN, LSTM",
        "Strengh and weakhnes": "Kelebihan: Kombinasi model meningkatkan akurasi. Kekurangan: Kompleksitas tinggi",
        "Summarize manual": "Menggabungkan CNN untuk ekstraksi fitur, RNN untuk pemilihan fitur, dan LSTM untuk klasifikasi"
    },
    {
        "No": 13,
        "JUDUL": "Fresh and Rotten Fruits Classification Using CNN and Transfer Learning",
        "LINK": "https://iieta.org/journals/ria/paper/10.18280/ria.340512",
        "TAHUN TERBIT": 2020,
        "PUBLISHER": "IIETA",
        "Research Objective": "Klasifikasi buah segar dan busuk menggunakan CNN dan transfer learning",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "CNN, Transfer Learning",
        "Strengh and weakhnes": "Kelebihan: Akurasi tinggi. Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menggunakan CNN dengan transfer learning untuk membedakan buah segar dan busuk"
    },
    {
        "No": 14,
        "JUDUL": "RESEARCH ON FRUIT IMAGE PROCESSING CLASSIFICANTION AND RECOGNITION",
        "LINK": "https://sia.alliancepress.org/2/1/30",
        "TAHUN TERBIT": 2021,
        "PUBLISHER": "Alliance Press",
        "Research Objective": "Menggunakan ResNet-50 untuk klasifikasi citra buah",
        "Dataset": "Fruits 360 dari Kaggle",
        "Techniques": "ResNet-50",
        "Strengh and weakhnes": "Kelebihan: Akurasi tinggi. Kekurangan: Fokus pada satu arsitektur",
        "Summarize manual": "Menerapkan ResNet-50 pada dataset Fruits 360 untuk klasifikasi buah"
    },
    {
        "No": 15,
        "JUDUL": "Classification of Fruits using Convolutional Neural Network",
        "LINK": "https://www.ijcaonline.org/archives/volume186/number22/minavathi-2024-ijca-923661.pdf",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "IJCA",
        "Research Objective": "Klasifikasi buah segar dan busuk menggunakan CNN",
        "Dataset": "Fruit Fresh and Rotten for Classification dari Kaggle",
        "Techniques": "CNN",
        "Strengh and weakhnes": "Kelebihan: Implementasi sederhana. Kekurangan: Dataset terbatas",
        "Summarize manual": "Menggunakan CNN untuk membedakan buah segar dan busuk pada tiga jenis buah"
    },
    {
        "No": 16,
        "JUDUL": "Classification of Fruits using Image Processing and Deep Neural Networks",
        "LINK": "https://www.ijarcs.info/index.php/Ijarcs/article/view/7156",
        "TAHUN TERBIT": 2025,
        "PUBLISHER": "IJARCS",
        "Research Objective": "Mengklasifikasikan gambar buah menggunakan AlexNet dan ResNet-50",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "AlexNet, ResNet-50",
        "Strengh and weakhnes": "Kelebihan: Akurasi tinggi (90-92%). Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menerapkan AlexNet dan ResNet-50 untuk klasifikasi gambar buah"
    },
    {
        "No": 17,
        "JUDUL": "Fruit classification using convolution neural networks",
        "LINK": "https://pubs.aip.org/aip/acp/article/2966/1/020011/3279443/Fruit-classification-using-convolution-neural",
        "TAHUN TERBIT": 2024,
        "PUBLISHER": "AIP Publishing",
        "Research Objective": "Mengklasifikasikan buah menggunakan CNN",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "CNN",
        "Strengh and weakhnes": "Kelebihan: Pendekatan sederhana. Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menggunakan CNN untuk klasifikasi citra buah"
    },
    {
        "No": 18,
        "JUDUL": "Design of fruit classification system based on deep learning",
        "LINK": "https://www.spiedigitallibrary.org/conference-proceedings-of-spie/12610/2671086/Design-of-fruit-classification-system-based-on-deep-learning/10.1117/12.2671086.full",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "SPIE",
        "Research Objective": "Merancang sistem klasifikasi buah berbasis deep learning untuk lingkungan industri",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "Multi-feature fusion, Pre-selection frame prediction",
        "Strengh and weakhnes": "Kelebihan: Cocok untuk industri. Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menggabungkan berbagai fitur dan strategi prediksi untuk klasifikasi buah di lingkungan industri"
    },
    {
        "No": 19,
        "JUDUL": "Fruits and vegetables classification using multi-layered CNN",
        "LINK": "https://pubs.aip.org/aip/acp/article/2721/1/070044/2904656/Fruits-and-vegetables-classification-using-multi",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "AIP Publishing",
        "Research Objective": "Klasifikasi buah dan sayuran menggunakan CNN multi-layer",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "Multi-layered CNN",
        "Strengh and weakhnes": "Kelebihan: Pendekatan AI untuk klasifikasi. Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menggunakan CNN multi-layer untuk klasifikasi buah dan sayuran"
    },
    {
        "No": 20,
        "JUDUL": "Fruit type classification using deep learning and feature fusion",
        "LINK": "https://www.sciencedirect.com/science/article/pii/S0168169923003782",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "ScienceDirect",
        "Research Objective": "Klasifikasi jenis buah menggunakan deep learning dan penggabungan fitur",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "Deep learning, Feature fusion",
        "Strengh and weakhnes": "Kelebihan: Pendekatan inovatif. Kekurangan: Detail dataset tidak lengkap",
        "Summarize manual": "Menggabungkan deep learning dan penggabungan fitur untuk klasifikasi jenis buah"
    },
    {
        "No": 21,
        "JUDUL": "Fruit Image Classification Using Deep Learning Algorithm: Systematic Review",
        "LINK": "https://journal.universitasmulia.ac.id/index.php/mst/article/view/356",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "Universitas Mulia",
        "Research Objective": "Meninjau algoritma deep learning untuk klasifikasi citra buah",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "CNN, MASK-RCNN, FASTER-RCNN, SSD",
        "Strengh and weakhnes": "Kelebihan: Tinjauan komprehensif. Kekurangan: Tidak ada eksperimen langsung",
        "Summarize manual": "Meninjau berbagai algoritma deep learning untuk klasifikasi citra buah"
    },
    {
        "No": 22,
        "JUDUL": "Fruits Classification and Detection Application Using Deep Learning",
        "LINK": "https://onlinelibrary.wiley.com/doi/full/10.1155/2022/4194874",
        "TAHUN TERBIT": 2022,
        "PUBLISHER": "Wiley",
        "Research Objective": "Mengembangkan aplikasi klasifikasi dan deteksi buah",
        "Dataset": "Fruits 360",
        "Techniques": "YOLOv3, CNN",
        "Strengh and weakhnes": "Kelebihan: Bisa klasifikasi & deteksi sekaligus. Kekurangan: Performa deteksi tergantung resolusi",
        "Summarize manual": "YOLOv3 dipadukan dengan CNN untuk klasifikasi dan deteksi buah"
    },
    {
        "No": 23,
        "JUDUL": "Fruit Quality and Defect Image Classification with Conditional GAN Data Augmentation",
        "LINK": "https://www.sciencedirect.com/science/article/pii/S0304423821007913",
        "TAHUN TERBIT": 2021,
        "PUBLISHER": "Elsevier",
        "Research Objective": "Meningkatkan klasifikasi kualitas buah dengan augmentasi data menggunakan Conditional GAN dan teknik pruning model",
        "Dataset": "Dataset buah lemon sehat dan rusak",
        "Techniques": "Conditional GAN, Transfer Learning, Model Pruning, Grad-CAM",
        "Strengh and weakhnes": "Kelebihan: Augmentasi data meningkatkan akurasi dan generalisasi; model lebih ringan melalui pruning. Kekurangan: Fokus pada satu jenis buah (lemon)",
        "Summarize manual": "Menggunakan Conditional GAN untuk menghasilkan citra sintetis buah sehat dan rusak, meningkatkan performa klasifikasi kualitas buah"
    },
    {
        "No": 24,
        "JUDUL": "Fruit Quality Assessment with Densely Connected Convolutional Neural Network",
        "LINK": "https://arxiv.org/abs/2212.04255",
        "TAHUN TERBIT": 2022,
        "PUBLISHER": "arXiv",
        "Research Objective": "Menilai kualitas buah menggunakan arsitektur DenseNet untuk klasifikasi multi-kelas",
        "Dataset": "19.526 gambar dari 6 jenis buah dengan 3 tingkat kualitas",
        "Techniques": "DenseNet, Deep Learning",
        "Strengh and weakhnes": "Kelebihan: Akurasi tinggi (99,67%) dalam klasifikasi kualitas buah. Kekurangan: Potensi overfitting pada dataset terbatas",
        "Summarize manual": "Menggunakan DenseNet untuk klasifikasi kualitas buah berdasarkan citra, mencapai akurasi tinggi dalam pengujian"
    },
    {
        "No": 25,
        "JUDUL": "Automated Fruit Classification Based on Deep Learning Utilizing YOLOv8",
        "LINK": "https://www.researchgate.net/publication/378511259_Automated_Fruit_Classification_Based_on_Deep_Learning_Utilizing_Yolov8",
        "TAHUN TERBIT": 2023,
        "PUBLISHER": "ResearchGate",
        "Research Objective": "Mengembangkan model deteksi dan klasifikasi buah otomatis menggunakan YOLOv8",
        "Dataset": "Tidak disebutkan secara spesifik",
        "Techniques": "YOLOv8, Deep Learning",
        "Strengh and weakhnes": "Kelebihan: Deteksi dan klasifikasi buah secara real-time dengan akurasi tinggi. Kekurangan: Detail dataset dan evaluasi terbatas",
        "Summarize manual": "Mengimplementasikan YOLOv8 untuk deteksi dan klasifikasi otomatis buah dalam rantai pasok"
    }
]


# Membuat DataFrame
df = pd.DataFrame(data)

# Simpan ke file Excel
file_path = "Klasifikasi_Citra_Buah_Jurnal.xlsx"
df.to_excel(file_path, index=False)

file_path
# Out:
# 'Klasifikasi_Citra_Buah_Jurnal.xlsx'

# %%
]

# %%
import pandas as pd


file_path = r"International Logistic Association Memberships.xlsx - Association ABC memberships.csv"
df = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 104
#       4 data = [
#       5     {
#       6         "No": 18,
#    (...)
#     100     }
#     101 ]
#     103 # Membaca file Excel sebelumnya
# --> 104 existing_df = pd.read_excel("/mnt/data/Klasifikasi_Citra_Buah_25_Jurnal.xlsx")
#     106 # Menggabungkan data baru
#     107 new_df = pd.DataFrame(data)
#
# File c:\Users\Faliq\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# ...

# %% [markdown]
# 2. Tampilkan 7 baris data awal dan tampilkan informasi dasar dataset. (2 point)

# %%
print(df.head(7))

# %%
print(df.info())

# %% [markdown]
# 3. Hitung jumlah iuran dan tentukan rata-rata iuran dari semua anggota (6 point)

# %%
df['Dues amount'] = df['Dues amount'].replace('[\$,]', '', regex=True).astype(float)

total_iuran = df['Dues amount'].sum()

rata_rata_iuran = df['Dues amount'].mean()

print(f"\nTotal Iuran: ${total_iuran:,.2f}")
print(f"Rata-rata Iuran: ${rata_rata_iuran:,.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Dues amount'] = df['Dues amount'].replace('[\$,]', '', regex=True).astype(float)
#       3 total_iuran = df['Dues amount'].sum()
#       5 rata_rata_iuran = df['Dues amount'].mean()
#
# NameError: name 'df' is not defined
